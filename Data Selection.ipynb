# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\welcome\Downloads\diabetes.csv')

# %%
# Head
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Tail
df.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# by columns
df['Glucose'][:5]
# Out:
# 0    148
# 1     85
# 2    183
# 3     89
# 4    137
# Name: Glucose, dtype: int64

# %%
# by slicing
df[:5]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df[-5:]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %% [markdown]
# ### Selection by Label

# %%
df.loc[0]
# Out:
# Pregnancies                   6.000
# Glucose                     148.000
# BloodPressure                72.000
# SkinThickness                35.000
# Insulin                       0.000
# BMI                          33.600
# DiabetesPedigreeFunction      0.627
# Age                          50.000
# Outcome                       1.000
# Name: 0, dtype: float64

# %%
df.loc[0,'BMI']
# Out:
# 33.6

# %%
print(df.loc[0,'BMI'].astype(int))
print(df.loc[0,'BMI'].astype(np.float16))
print(df.loc[0,'BMI'].astype(np.float64))
# Out:
# 33
# 33.6
# 33.6

# %%
df.loc[0,{"Glucose","BMI"}]
# Out:
# BMI         33.6
# Glucose    148.0
# Name: 0, dtype: float64

# %%
df.loc[0:5,{"Glucose","BMI"}]
# Out:
#     BMI  Glucose
# 0  33.6      148
# 1  26.6       85
# 2  23.3      183
# 3  28.1       89
# 4  43.1      137
# 5  25.6      116

# %% [markdown]
# ### Selection by Position

# %%
df.iloc[10]
# Out:
# Pregnancies                   4.000
# Glucose                     110.000
# BloodPressure                92.000
# SkinThickness                 0.000
# Insulin                       0.000
# BMI                          37.600
# DiabetesPedigreeFunction      0.191
# Age                          30.000
# Outcome                       0.000
# Name: 10, dtype: float64

# %%
df.iloc[0:6,:]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0

# %%
df.iloc[2:6,0:5]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168
# 5            5      116             74              0        0

# %% [markdown]
# ### Data filtering

# %%
df[df['BMI']>40].head()
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4             0      137             40             35      168  43.1
# 16            0      118             84             47      230  45.8
# 18            1      103             30             38       83  43.3
# 41            7      133             84              0        0  40.2
# 43            9      171            110             24      240  45.4
#
#     DiabetesPedigreeFunction  Age  Outcome
# 4                      2.288   33        1
# 16                     0.551   31        1
# 18                     0.183   33        0
# 41                     0.696   37        0
# 43                     0.721   54        1

# %%
df[df['Outcome']==1].head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 2            8      183             64              0        0  23.3
# 4            0      137             40             35      168  43.1
# 6            3       78             50             32       88  31.0
# 8            2      197             70             45      543  30.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 2                     0.672   32        1
# 4                     2.288   33        1
# 6                     0.248   26        1
# 8                     0.158   53        1

# %%
df[df['Pregnancies'].isin([5,3])].head()
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 14            5      166             72             19      175  25.8
# 20            3      126             88             41      235  39.3
# 29            5      117             92              0        0  34.1
#
#     DiabetesPedigreeFunction  Age  Outcome
# 5                      0.201   30        0
# 6                      0.248   26        1
# 14                     0.587   51        1
# 20                     0.704   27        0
# 29                     0.337   38        0

# %%
df[~df['Pregnancies'].isin([5,3])].head() ##Negation
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
